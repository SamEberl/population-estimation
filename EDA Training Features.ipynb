# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from tqdm import tqdm

import matplotlib.pyplot as plt
from scipy.stats import skew, norm
from scipy.stats import pearsonr
from scipy import stats

import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from catboost import CatBoostRegressor
#import xgboost as xgb
from sklearn.metrics import mean_squared_error

import optuna

# %config InlineBackend.figure_format = 'retina' #set 'png' here when working on notebook
# %matplotlib inline

# %%
np.set_printoptions(linewidth=100)
#torch.set_printoptions(linewidth=140, sci_mode=False, edgeitems=7)
pd.set_option('display.width', 100)

# %%
#df_train = pd.read_csv('/home/sam/Desktop/train_features.csv')
df_train = pd.read_csv('/home/sam/Desktop/train_features_full.csv')
df_val = pd.read_csv('/home/sam/Desktop/val_features_sen2spring_full.csv')
df_train
# Out:
#                0         1         2         3         4         5         6         7         8  \
# 0      -2.258663  1.293138 -2.996038 -0.575559 -2.283529 -0.188085  0.119290 -1.712181  0.589475
# 1      -1.047828  1.884326 -2.331410 -2.225147  0.931954 -0.292078  3.533413 -2.351596 -2.676253
# 2       1.256264  1.287917 -1.623398 -0.807601 -0.191629 -1.443249  0.009767 -2.634470  0.891560
# 3       0.275954  0.945337 -1.630023 -2.374230  1.059232 -1.005715 -0.644017 -4.423538 -2.071929
# 4      -3.807551  0.863325 -2.075258 -2.690388  2.386226  0.415941 -0.783520 -3.846460 -2.425034
# ...          ...       ...       ...       ...       ...       ...       ...       ...       ...
# 119789 -0.824774  1.542952  1.281719 -4.999974  3.168676  0.668745 -1.308084 -4.155051  1.000480
# 119790 -1.761228  1.442533 -0.817491 -2.234642 -0.201066 -0.170385 -0.894437 -4.775628 -0.681192
# 119791  0.436338  1.372671 -1.780801 -3.187654 -0.935278  1.176084 -1.379797 -0.845491  1.186493
# 119792 -1.662462  1.163252 -0.302995 -3.136119  0.586972  0.439120 -0.788928 -3.858171 -0.338165
# 119793 -2.102682  1.886664 -3.001636 -1.576295 -1.479113  0.157883  1.196984 -4.656555 -2.861898
#
#                9  ...       375       376       377       378       379       380       381  \
# 0       4.297632  ... -0.904086  4.048374  1.537473  3.967812  0.724500 -2.137770  0.225233
# 1       5.435595  ... -3.764316  3.170474 -2.296357 -1.100516 -1.618941  0.029144 -0.384293
# 2       4.414039  ... -1.016576  3.451053  0.256072 -1.164894 -0.288734 -2.942119 -1.182515
# 3       4.296110  ... -3.589805  3.903207 -2.914503 -0.367495 -0.208813 -4.057783  4.047244
# 4       3.960075  ... -0.798793 -2.056659 -2.218732  1.573842 -0.626472 -0.385242 -2.789692
# ...          ...  ...       ...       ...       ...       ...       ...       ...       ...
# 119789  4.302743  ... -1.625028  1.214373 -0.913813 -3.537408 -0.634347 -1.033690 -2.429408
# 119790  1.449376  ... -2.359940  0.805239 -1.213802 -1.550161 -1.110322 -0.922525 -2.532472
# 119791  0.649688  ... -2.207478  2.019400 -1.127565 -3.842577 -1.937280 -2.486459 -1.381168
# 119792  0.836020  ... -1.872448  3.181392 -0.101483 -4.183690 -1.696994 -1.138966 -2.282225
# 119793  4.398842  ... -3.305609  3.749660 -0.823990 -1.145097  0.556207 -2.507122  0.527652
#
#              382       383  PopCount
# 0       0.428981  3.685380    1875.0
# 1       0.185415  1.636488   15623.0
# 2       0.441435  1.458271       7.0
# 3       0.160762  4.224138       0.0
# 4      -0.010004  1.100672       0.0
# ...          ...       ...       ...
# 119789 -0.480590  1.873861      84.0
# 119790  0.485393 -0.392721     340.0
# 119791 -2.777955  0.076584       0.0
# 119792 -1.565296  0.582951       0.0
# 119793 -0.979811  4.170392    6720.0
#
# [119794 rows x 385 columns]

# %%
df_val
# Out:
#               0         1         2         3         4         5         6         7         8  \
# 0     -1.572946  1.701881 -1.744668 -1.730602 -0.458118 -0.480903  0.004936 -2.934512 -0.818544
# 1     -1.855960  1.814494 -1.576891 -2.437454 -1.194013 -0.278126 -1.129630 -4.145254 -0.585838
# 2     -1.010746  1.479656  0.344912 -2.146713  0.840336 -0.249672 -1.312627 -6.639433 -0.255110
# 3     -0.314007  0.807744 -2.964665 -4.845000  1.295797  0.673035  0.651277 -3.669301 -0.247917
# 4      0.203178  1.803536 -4.787431  1.494698 -0.443997  0.313879 -1.897964 -6.117711 -1.774299
# ...         ...       ...       ...       ...       ...       ...       ...       ...       ...
# 18287 -2.106102  2.871209 -2.973956 -0.546221  0.330561 -0.169984 -1.251647 -3.993633 -2.159011
# 18288 -1.657586  1.100706  0.976617 -3.024606  1.079489 -0.312136  0.126198 -5.031255  0.498281
# 18289 -0.178578  1.560148 -1.120029 -0.499108 -1.486722 -1.027839 -1.026397 -3.133717 -0.289160
# 18290  2.082999  0.684164 -1.064517 -0.549051 -0.293873 -0.841102 -0.660363 -4.407497  1.301448
# 18291  0.766446 -0.164631 -0.285186 -1.977635 -1.825889 -0.739167  1.857615 -4.641925  1.163677
#
#               9  ...       375       376       377       378       379       380       381  \
# 0      3.396896  ... -2.807557  6.865187  0.268724  0.229954 -1.476011 -2.797969 -2.243979
# 1      3.596437  ... -4.460546  5.878555  0.327318 -1.810410 -0.330138 -3.631624  0.278670
# 2      3.159652  ... -1.023940  3.038432 -0.953151 -0.991137 -0.290495 -2.345687 -2.457734
# 3      4.373765  ... -0.749071  0.456789 -3.813541 -2.663855 -0.790794 -1.335525 -0.750081
# 4      3.977978  ... -1.538388  0.713208 -0.582650 -0.841400  0.669676 -2.107170 -2.063743
# ...         ...  ...       ...       ...       ...       ...       ...       ...       ...
# 18287  2.619805  ... -2.938044  2.310738 -1.316753 -1.937984  0.250398 -2.847088 -1.065091
# 18288  3.156191  ... -2.585756  1.810582 -2.604308 -1.773614  0.172661 -3.445771 -1.286131
# 18289  4.442442  ... -2.104027  3.444005 -1.231276  0.265463 -0.312796 -3.531531 -1.670099
# 18290  3.713321  ... -2.812293  3.040470 -1.032688 -0.272343 -0.036352 -5.344829  0.393127
# 18291  4.180957  ... -3.247276  1.663621 -1.050273 -1.721361 -0.613800 -4.815866 -1.637112
#
#             382       383  PopCount
# 0      0.171131  2.173406       0.0
# 1      0.159752  2.924775       0.0
# 2     -1.344143  1.241961       0.0
# 3     -2.740548  2.082489       0.0
# 4     -1.968132  2.481665       0.0
# ...         ...       ...       ...
# 18287 -2.278544  6.098589   15762.0
# 18288 -0.743595  2.813748    5519.0
# 18289  0.916649  1.778367    5105.0
# 18290 -0.878283  2.011075     219.0
# 18291 -2.691933  2.334350    2879.0
#
# [18292 rows x 385 columns]

# %%
df_train.isna().sum().sum()
# Out:
# 0

# %%
df_val.isna().sum().sum()
# Out:
# 0

# %%
df_train['PopCount']
# Out:
# 0          1875.0
# 1         15623.0
# 2             7.0
# 3             0.0
# 4             0.0
#            ...
# 119789       84.0
# 119790      340.0
# 119791        0.0
# 119792        0.0
# 119793     6720.0
# Name: PopCount, Length: 119794, dtype: float64

# %%
'''
# Delete values in ranges that have to many. Mainly values close to 0
n = 2000  # Number of buckets
x = 400  # Maximum number of values per bucket

# Calculate range and bucket size
value_range = df_train['PopCount'].max() - df_train['PopCount'].min()
bucket_size = value_range / n

bucket_counts = {}

# Populate bucket counts
for index, row in df_train.iterrows():
    bucket_index = int((row['PopCount'] - df_train['PopCount'].min()) / bucket_size)
    if bucket_index not in bucket_counts:
        bucket_counts[bucket_index] = 0
    bucket_counts[bucket_index] += 1

# Create a list of row indices to be deleted
rows_to_delete = []
for index, row in df_train.iterrows():
    bucket_index = int((row['PopCount'] - df_train['PopCount'].min()) / bucket_size)
    if bucket_counts.get(bucket_index, 0) > x:
        rows_to_delete.append(index)
        bucket_counts[bucket_index] -= 1

# Delete rows from the DataFrame
df_filtered = df_train.drop(rows_to_delete)
df_train = df_filtered
'''
# Out:
# "\n# Delete values in ranges that have to many. Mainly values close to 0\nn = 2000  # Number of buckets\nx = 400  # Maximum number of values per bucket\n\n# Calculate range and bucket size\nvalue_range = df_train['PopCount'].max() - df_train['PopCount'].min()\nbucket_size = value_range / n\n\nbucket_counts = {}\n\n# Populate bucket counts\nfor index, row in df_train.iterrows():\n    bucket_index = int((row['PopCount'] - df_train['PopCount'].min()) / bucket_size)\n    if bucket_index not in bucket_counts:\n        bucket_counts[bucket_index] = 0\n    bucket_counts[bucket_index] += 1\n\n# Create a list of row indices to be deleted\nrows_to_delete = []\nfor index, row in df_train.iterrows():\n    bucket_index = int((row['PopCount'] - df_train['PopCount'].min()) / bucket_size)\n    if bucket_counts.get(bucket_index, 0) > x:\n        rows_to_delete.append(index)\n        bucket_counts[bucket_index] -= 1\n\n# Delete rows from the DataFrame\ndf_filtered = df_train.drop(rows_to_delete)\ndf_train = df_filtered\n"

# %%
df_train = df_train[df_train['PopCount']!=0]
df_val = df_val[df_val['PopCount']!=0]

# %%
sns.displot(df_train['PopCount'])
#sns.displot(df_train[df_train['PopCount'] > 400]['PopCount'])
# Out:
# /home/sam/anaconda3/envs/nb_env/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df_val['PopCount'].describe()
# Out:
# count    12527.000000
# mean      1691.717171
# std       3675.438279
# min          1.000000
# 25%         39.000000
# 50%        232.000000
# 75%       1624.000000
# max      44636.000000
# Name: PopCount, dtype: float64

# %%
df_train['PopCount'].describe()
# Out:
# count    87617.000000
# mean      1469.183092
# std       3082.143861
# min          1.000000
# 25%         40.000000
# 50%        253.000000
# 75%       1532.000000
# max      53119.000000
# Name: PopCount, dtype: float64

# %%
df_train['PopCount'].skew()
# Out:
# 4.961530898862154

# %%
df_train['PopCount'].kurt()
# Out:
# 38.93009906208681

# %%
target = df_train['PopCount']
target_transformed = np.log1p(target)

# %%
target_transformed = np.log1p(target / 253.0)

# %%
fig, ax = plt.subplots(1, 2, figsize= (15, 5))
fig.suptitle("qq-plot & distribution PopCount ", fontsize=15)

sm.qqplot(target_transformed, stats.t, distargs=(4,),fit=True, line="45", ax=ax[0])
sns.histplot(target_transformed, kde=True, ax=ax[1])
plt.show()

# %%
target = df_train['PopCount']
best_fit = stats.expon.fit(target)

# Plot the histogram of data and the best-fit distribution
plt.hist(target, bins=50, density=True, alpha=0.6, color='blue')
x_range = np.linspace(min(target), max(target), 100)
plt.plot(x_range, stats.expon.pdf(x_range, *best_fit), color='red')
plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Data and Best-Fit Expon Distribution')
plt.show()

# %%
best_fit = stats.exponweib.fit(target)

# Plot the histogram of data and the best-fit Weibull distribution
plt.hist(target, bins=100, density=True, alpha=0.6, color='blue')
x_range = np.linspace(min(target), max(target), 100)
plt.plot(x_range, stats.exponweib.pdf(x_range, *best_fit), color='red')
plt.xlabel('Data')
plt.ylabel('Density')
plt.title('Data and Best-Fit Weibull Distribution')
plt.ylim(0, 0.0002)
plt.show()

# %% [markdown]
# 1. a corresponds to the offset parameter (if applicable).
# 2. c corresponds to the shape parameter.
# 3. loc corresponds to the location parameter.
# 4. scale corresponds to the scale parameter.

# %%
print(f'a    : {best_fit[0]}')
print(f'c    : {best_fit[1]}')
print(f'loc  : {best_fit[2]}')
print(f'scale: {best_fit[3]}')
print(best_fit)
# Out:
# a    : 0.7147368232896316
# c    : 0.5881668804139415
# loc  : 0.9999999999999999
# scale: 1258.1695617401892
# (0.7147368232896316, 0.5881668804139415, 0.9999999999999999, 1258.1695617401892)

# %%
from scipy.integrate import quad
lower_limit = 0
upper_limit = np.inf
def dist(x_range):
    return stats.exponweib.pdf(x_range, *best_fit)
area, error = quad(dist, lower_limit, upper_limit)
print(f'area: {area}   error: {error}')
# Out:
# area: 0.999999999634285   error: 4.291678123991005e-12

# %%
# Create a figure with subplots
fig, ax = plt.subplots(1, 2, figsize=(10, 4))

# Q-Q plot using the Weibull distribution
#weibull_dist = stats.exponweib(2.4428138246958326, 0.5733831176869839, -1.7650834342453228, 1041.84099564792)
weibull_dist = stats.exponweib(*best_fit)
sm.qqplot(df_train['PopCount'], dist=weibull_dist, fit=False, line="r", ax=ax[0])
ax[0].set_title("Q-Q Plot using Weibull Distribution")

# Q-Q plot using the Exponential distribution
sm.qqplot(df_train['PopCount'], dist=stats.expon, fit=True, line="r", ax=ax[1])
ax[1].set_title("Q-Q Plot using Exponential Distribution")

plt.tight_layout()
plt.show()

# %%
corr = df_train.corr()
#plt.figure(figsize=(20, 10))
#sns.heatmap(corr, cmap='viridis', linewidths=0.5)

# %%
#PopCount correlation matrix
k = 20 #number of variables for heatmap
cols = corr.nlargest(k, 'PopCount')['PopCount'].index
#cols = corr.nsmallest(k, 'PopCount')['PopCount'].index
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.25)
plt.figure(figsize=(20, 10))
hm = sns.heatmap(cm, cbar=True, annot=True, fmt='.2f', annot_kws={'size': 12}, yticklabels=cols.values, xticklabels=cols.values, linewidths=0.5)
plt.show()

# %%
df_train = df_train[cols]
df_val = df_val[cols]
print(f'df_train: {df_train.shape}   df_val: {df_val.shape}')
# Out:
# df_train: (87617, 20)   df_val: (12527, 20)

# %%
sns.histplot(df_train['209'])
# Out:
# <Axes: xlabel='209', ylabel='Count'>

# %%
target = df_train['PopCount']
target_log = np.log1p(target)

ytrain = target
xtrain = df_train.drop('PopCount', axis=1)

#--- val data ---

val_target = df_val['PopCount']
val_target_log = np.log1p(val_target)

yval = val_target
xval = df_val.drop('PopCount', axis=1)

X_train, X_val, y_train, y_val = xtrain, xval, ytrain, yval

#X_train, X_val, y_train, y_val = train_test_split(xtrain, ytrain, test_size=0.1, shuffle=False, random_state=42)
#X_train, y_train = xtrain, ytrain
#X_train

# %%
def objective(trial):
    params = {
        "iterations": 1000,
        "learning_rate": trial.suggest_float("learning_rate", 0.1, 0.1, log=True),
        "depth": trial.suggest_int("depth", 2, 10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.05, 1.0),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 1, 10000),
    }

    model = CatBoostRegressor(**params, silent=True)
    model.fit(X_train, y_train)
    predictions = model.predict(X_val)
    rmse = mean_squared_error(y_val, predictions, squared=False)
    return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)
# Out:
# [I 2023-09-03 14:53:06,027] A new study created in memory with name: no-name-7c146c85-caed-411a-95be-20922d8aadee
# [I 2023-09-03 14:53:09,864] Trial 0 finished with value: 2803.78209250619 and parameters: {'learning_rate': 0.1, 'depth': 8, 'subsample': 0.0842695134803946, 'colsample_bylevel': 0.24215138622414328, 'min_data_in_leaf': 85, 'l2_leaf_reg': 8031}. Best is trial 0 with value: 2803.78209250619.
# [I 2023-09-03 14:53:15,458] Trial 1 finished with value: 2792.389447881068 and parameters: {'learning_rate': 0.1, 'depth': 8, 'subsample': 0.8299110407038348, 'colsample_bylevel': 0.25945777354704674, 'min_data_in_leaf': 81, 'l2_leaf_reg': 4613}. Best is trial 1 with value: 2792.389447881068.
# [I 2023-09-03 14:53:35,882] Trial 2 finished with value: 2825.3726449250303 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.3880397445419133, 'colsample_bylevel': 0.6858176064277484, 'min_data_in_leaf': 47, 'l2_leaf_reg': 8485}. Best is trial 1 with value: 2792.389447881068.
# [I 2023-09-03 14:53:52,975] Trial 3 finished with value: 2822.657272752098 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.6854452588279615, 'colsample_bylevel': 0.9352040223268094, 'min_data_in_leaf': 95, 'l2_leaf_reg': 9308}. Best is trial 1 with value: 2792.389447881068.
# [I 2023-09-03 14:53:54,574] Trial 4 finished with value: 2845.278800576361 and parameters: {'learning_rate': 0.1, 'depth': 4, 'subsample': 0.36477153305251075, 'colsample_bylevel': 0.8599018075579368, 'min_data_in_leaf': 3, 'l2_leaf_reg': 8481}. Best is trial 1 with value: 2792.389447881068.
# [I 2023-09-03 14:53:56,387] Trial 5 finished with value: 2831.325408295088 and parameters: {'learning_rate': 0.1, 'depth': 4, 'subsample': 0.5466593593572318, 'colsample_bylevel': 0.825799859092921, 'min_data_in_leaf': 97, 'l2_leaf_reg': 5291}. Best is trial 1 with value: 2792.389447881068.
# [I 2023-09-03 14:53:58,075] Trial 6 finished with value: 2791.7043289135436 and parameters: {'learning_rate': 0.1, 'depth': 5, 'subsample': 0.2545055356702285, 'colsample_bylevel': 0.5930418164962318, 'min_data_in_leaf': 78, 'l2_leaf_reg': 3152}. Best is trial 6 with value: 2791.7043289135436.
# [I 2023-09-03 14:54:02,221] Trial 7 finished with value: 2795.7841162965433 and parameters: {'learning_rate': 0.1, 'depth': 7, 'subsample': 0.488093918823177, 'colsample_bylevel': 0.6112867008232511, 'min_data_in_leaf': 62, 'l2_leaf_reg': 5543}. Best is trial 6 with value: 2791.7043289135436.
# [I 2023-09-03 14:54:24,047] Trial 8 finished with value: 2712.8005807701948 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.23673419948144164, 'colsample_bylevel': 0.7515196804210613, 'min_data_in_leaf': 2, 'l2_leaf_reg': 533}. Best is trial 8 with value: 2712.8005807701948.
# [I 2023-09-03 14:54:25,513] Trial 9 finished with value: 2852.831910645071 and parameters: {'learning_rate': 0.1, 'depth': 3, 'subsample': 0.861229972205661, 'colsample_bylevel': 0.13389811070038016, 'min_data_in_leaf': 32, 'l2_leaf_reg': 8004}. Best is trial 8 with value: 2712.8005807701948.
# [I 2023-09-03 14:54:39,619] Trial 10 finished with value: 2723.5342942965676 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.05714431200109138, 'colsample_bylevel': 0.4565408523474503, 'min_data_in_leaf': 1, 'l2_leaf_reg': 513}. Best is trial 8 with value: 2712.8005807701948.
# [I 2023-09-03 14:54:53,627] Trial 11 finished with value: 2694.4333953303735 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.07556097173079183, 'colsample_bylevel': 0.4430175980681734, 'min_data_in_leaf': 1, 'l2_leaf_reg': 127}. Best is trial 11 with value: 2694.4333953303735.
# [I 2023-09-03 14:55:07,795] Trial 12 finished with value: 2702.2542783894746 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.174339227786659, 'colsample_bylevel': 0.4347311144559813, 'min_data_in_leaf': 22, 'l2_leaf_reg': 52}. Best is trial 11 with value: 2694.4333953303735.
# [I 2023-09-03 14:55:09,670] Trial 13 finished with value: 2755.3853453290812 and parameters: {'learning_rate': 0.1, 'depth': 6, 'subsample': 0.14083395757161576, 'colsample_bylevel': 0.44718708274092955, 'min_data_in_leaf': 22, 'l2_leaf_reg': 2080}. Best is trial 11 with value: 2694.4333953303735.
# [I 2023-09-03 14:55:14,848] Trial 14 finished with value: 2752.439649902524 and parameters: {'learning_rate': 0.1, 'depth': 8, 'subsample': 0.18287829325782434, 'colsample_bylevel': 0.41156230268312005, 'min_data_in_leaf': 21, 'l2_leaf_reg': 1990}. Best is trial 11 with value: 2694.4333953303735.
# [I 2023-09-03 14:55:23,439] Trial 15 finished with value: 2692.8857946418707 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.26761420028692123, 'colsample_bylevel': 0.3489970200913607, 'min_data_in_leaf': 18, 'l2_leaf_reg': 113}. Best is trial 15 with value: 2692.8857946418707.
# [I 2023-09-03 14:55:25,900] Trial 16 finished with value: 2747.998269077006 and parameters: {'learning_rate': 0.1, 'depth': 7, 'subsample': 0.05694668623713359, 'colsample_bylevel': 0.3255771471024783, 'min_data_in_leaf': 41, 'l2_leaf_reg': 1877}. Best is trial 15 with value: 2692.8857946418707.
# [I 2023-09-03 14:55:36,907] Trial 17 finished with value: 2781.411684644006 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.3005073815939952, 'colsample_bylevel': 0.5564302969472988, 'min_data_in_leaf': 13, 'l2_leaf_reg': 3738}. Best is trial 15 with value: 2692.8857946418707.
# [I 2023-09-03 14:55:37,758] Trial 18 finished with value: 2879.9183271083775 and parameters: {'learning_rate': 0.1, 'depth': 2, 'subsample': 0.31460829498687615, 'colsample_bylevel': 0.058834881978814424, 'min_data_in_leaf': 61, 'l2_leaf_reg': 1340}. Best is trial 15 with value: 2692.8857946418707.
# [I 2023-09-03 14:55:45,596] Trial 19 finished with value: 2803.4481557724725 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.1819416541399454, 'colsample_bylevel': 0.32309669150329595, 'min_data_in_leaf': 33, 'l2_leaf_reg': 6352}. Best is trial 15 with value: 2692.8857946418707.
# [I 2023-09-03 14:55:49,511] Trial 20 finished with value: 2782.0542786497776 and parameters: {'learning_rate': 0.1, 'depth': 7, 'subsample': 0.42115953085689556, 'colsample_bylevel': 0.5547973957779745, 'min_data_in_leaf': 14, 'l2_leaf_reg': 3229}. Best is trial 15 with value: 2692.8857946418707.
# [I 2023-09-03 14:56:04,396] Trial 21 finished with value: 2689.32311800081 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.16648271134375908, 'colsample_bylevel': 0.46300211205322434, 'min_data_in_leaf': 14, 'l2_leaf_reg': 51}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:56:14,453] Trial 22 finished with value: 2739.8414588045434 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.2486988195451768, 'colsample_bylevel': 0.46792961046484216, 'min_data_in_leaf': 11, 'l2_leaf_reg': 1267}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:56:26,692] Trial 23 finished with value: 2697.430066354973 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.12754727723349485, 'colsample_bylevel': 0.36382605110660704, 'min_data_in_leaf': 31, 'l2_leaf_reg': 47}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:56:36,488] Trial 24 finished with value: 2730.2930534786597 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.12839361185401227, 'colsample_bylevel': 0.5049205124218485, 'min_data_in_leaf': 10, 'l2_leaf_reg': 1051}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:56:41,386] Trial 25 finished with value: 2761.8468360953198 and parameters: {'learning_rate': 0.1, 'depth': 8, 'subsample': 0.21838143425738477, 'colsample_bylevel': 0.36441019756224985, 'min_data_in_leaf': 26, 'l2_leaf_reg': 2401}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:57:01,879] Trial 26 finished with value: 2726.690448658296 and parameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.3198246042791571, 'colsample_bylevel': 0.6437739827819692, 'min_data_in_leaf': 40, 'l2_leaf_reg': 753}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:57:03,700] Trial 27 finished with value: 2764.001666486499 and parameters: {'learning_rate': 0.1, 'depth': 6, 'subsample': 0.06167566415073886, 'colsample_bylevel': 0.5225951932321831, 'min_data_in_leaf': 17, 'l2_leaf_reg': 2638}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:57:13,557] Trial 28 finished with value: 2783.7630643944144 and parameters: {'learning_rate': 0.1, 'depth': 9, 'subsample': 0.14599001195042946, 'colsample_bylevel': 0.49899976729979606, 'min_data_in_leaf': 7, 'l2_leaf_reg': 4243}. Best is trial 21 with value: 2689.32311800081.
# [I 2023-09-03 14:57:17,530] Trial 29 finished with value: 2792.6462411107964 and parameters: {'learning_rate': 0.1, 'depth': 8, 'subsample': 0.11006845586329812, 'colsample_bylevel': 0.246854596944142, 'min_data_in_leaf': 57, 'l2_leaf_reg': 6745}. Best is trial 21 with value: 2689.32311800081.

# %%
print('Best hyperparameters:', study.best_params)
print('Best RMSE:', study.best_value)
# Out:
# Best hyperparameters: {'learning_rate': 0.1, 'depth': 10, 'subsample': 0.16648271134375908, 'colsample_bylevel': 0.46300211205322434, 'min_data_in_leaf': 14, 'l2_leaf_reg': 51}
# Best RMSE: 2689.32311800081

# %%
params = {'max_leaves': 8,
           'depth': 3,
           'od_wait': 200,
           #'l2_leaf_reg': 3,
          'l2_leaf_reg': 17,
           'iterations': 20,
           #'model_size_reg': 0.7,
          'model_size_reg': 1.7,
           #'learning_rate': 0.05,
          'learning_rate': 0.5,
           'random_seed': 42 }

# %%
model = CatBoostRegressor(**params)

# %%
grid = {
    'learning_rate': [0.1, 0.05, 0.01, 0.005],
    'depth': [3, 5, 7],
    'l2_leaf_reg': [1, 10, 100, 1000, 10000],
    'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']
}

# %%
randomized_search_result = model.randomized_search(grid, X=X_train, y=y_train, verbose=False, n_iter=10,)

feature_importance = model.get_feature_importance(prettified=True)
print ('feature_importance', feature_importance)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 randomized_search_result = model.randomized_search(grid, X=X_train, y=y_train, verbose=False, n_iter=10,)
#       3 feature_importance = model.get_feature_importance(prettified=True)
#       4 print ('feature_importance', feature_importance)
#
# NameError: name 'model' is not defined

# %%
model.get_params()
# Out:
# {'iterations': 300,
#  'learning_rate': 0.1,
#  'depth': 7,
#  'l2_leaf_reg': 1000,
#  'loss_function': 'RMSE',
#  'random_seed': 42,
#  'subsample': 0.5636712389804519,
#  'colsample_bylevel': 0.286574054081783,
#  'grow_policy': 'Lossguide',
#  'min_data_in_leaf': 29}

# %%
params = {#'max_leaves': 5,
          'learning_rate': 0.05, 
          'depth': 10, 
          'subsample': 0.5636712389804519, 
          'colsample_bylevel': 0.286574054081783, 
          #'min_data_in_leaf': 2,
          'l2_leaf_reg': 1000,
          'iterations': 2000,
          #'model_size_reg': 0.7,
          'grow_policy': 'Lossguide',
          'random_seed': 42
         }

# %%
params = {'learning_rate': 0.05, 
          'depth': 6, 
          'subsample': 0.1, 
          'colsample_bylevel': 0.95, 
          'min_data_in_leaf': 90,
          'iterations': 3000,
          'l2_leaf_reg': 250}

# %%
model = CatBoostRegressor(**params)

# %%
model.fit(X_train, y_train, 
          eval_set=(X_val, y_val),
          use_best_model=True,
          plot=True,
          verbose=25)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 3041.8465589	test: 3645.0721394	best: 3645.0721394 (0)	total: 3.15ms	remaining: 9.43s
# 25:	learn: 2515.3611588	test: 3140.6856333	best: 3140.6856333 (25)	total: 60.2ms	remaining: 6.88s
# 50:	learn: 2357.5817064	test: 2983.4633138	best: 2983.4633138 (50)	total: 110ms	remaining: 6.33s
# 75:	learn: 2295.4058185	test: 2914.6867335	best: 2914.6867335 (75)	total: 158ms	remaining: 6.1s
# 100:	learn: 2264.6824199	test: 2884.7999412	best: 2884.7999412 (100)	total: 208ms	remaining: 5.97s
# 125:	learn: 2242.8600427	test: 2861.0815748	best: 2861.0815748 (125)	total: 263ms	remaining: 5.99s
# 150:	learn: 2225.7698735	test: 2846.1272500	best: 2846.1272500 (150)	total: 313ms	remaining: 5.9s
# 175:	learn: 2213.3187089	test: 2837.1267632	best: 2837.1267632 (175)	total: 364ms	remaining: 5.84s
# 200:	learn: 2200.9508089	test: 2826.0994786	best: 2826.0994786 (200)	total: 415ms	remaining: 5.78s
# 225:	learn: 2190.9764021	test: 2821.8376720	best: 2821.8376720 (225)	total: 469ms	remaining: 5.76s
# 250:	learn: 2181.7471332	test: 2815.0039278	best: 2815.0039278 (250)	total: 518ms	remaining: 5.67s
# 275:	learn: 2172.8570128	test: 2808.7655594	best: 2808.7655594 (275)	total: 570ms	remaining: 5.62s
# 300:	learn: 2164.6959439	test: 2802.8535313	best: 2802.8535313 (300)	total: 624ms	remaining: 5.6s
# 325:	learn: 2158.0543359	test: 2797.4139200	best: 2797.4139200 (325)	total: 679ms	remaining: 5.57s
# 350:	learn: 2150.5514585	test: 2792.0024308	best: 2792.0024308 (350)	total: 727ms	remaining: 5.48s
# 375:	learn: 2144.4014640	test: 2788.8612757	best: 2788.7831798 (374)	total: 773ms	remaining: 5.39s
# 400:	learn: 2137.6308950	test: 2783.9075790	best: 2783.9075790 (400)	total: 821ms	remaining: 5.32s
# 425:	learn: 2130.4890366	test: 2780.2568047	best: 2780.1432339 (424)	total: 878ms	remaining: 5.3s
# 450:	learn: 2124.0596059	test: 2776.2600831	best: 2776.2600831 (450)	total: 925ms	remaining: 5.23s
# 475:	learn: 2118.3129114	test: 2772.7420695	best: 2772.6649388 (474)	total: 984ms	remaining: 5.21s
# 500:	learn: 2113.7210966	test: 2770.6161331	best: 2770.6161331 (500)	total: 1.04s	remaining: 5.21s
# 525:	learn: 2108.2239337	test: 2767.3651830	best: 2767.3651830 (525)	total: 1.1s	remaining: 5.17s
# 550:	learn: 2103.8227689	test: 2765.1622555	best: 2765.1622555 (550)	total: 1.15s	remaining: 5.1s
# 575:	learn: 2099.8093262	test: 2763.1561276	best: 2763.1270640 (568)	total: 1.2s	remaining: 5.03s
# 600:	learn: 2094.9227061	test: 2759.6738277	best: 2759.6738277 (600)	total: 1.24s	remaining: 4.96s
# 625:	learn: 2089.9688511	test: 2757.0839387	best: 2757.0839387 (625)	total: 1.3s	remaining: 4.93s
# 650:	learn: 2085.5615148	test: 2753.7758060	best: 2753.7758060 (650)	total: 1.35s	remaining: 4.86s
# 675:	learn: 2080.7447499	test: 2750.9530401	best: 2750.9530401 (675)	total: 1.4s	remaining: 4.81s
# 700:	learn: 2076.1042701	test: 2748.4683659	best: 2748.4683659 (700)	total: 1.46s	remaining: 4.78s
# 725:	learn: 2071.8347562	test: 2746.1848029	best: 2746.1848029 (725)	total: 1.51s	remaining: 4.74s
# 750:	learn: 2067.2674583	test: 2742.9020731	best: 2742.9020731 (750)	total: 1.57s	remaining: 4.71s
# 775:	learn: 2063.5440781	test: 2741.3498322	best: 2741.2728568 (773)	total: 1.62s	remaining: 4.66s
# 800:	learn: 2059.7306838	test: 2739.7721931	best: 2739.7676868 (799)	total: 1.68s	remaining: 4.61s
# 825:	learn: 2056.8397705	test: 2738.5400230	best: 2738.5400230 (825)	total: 1.73s	remaining: 4.55s
# 850:	learn: 2053.2919038	test: 2736.7957252	best: 2736.7957252 (850)	total: 1.78s	remaining: 4.49s
# 875:	learn: 2050.2809975	test: 2735.6835761	best: 2735.6829933 (874)	total: 1.82s	remaining: 4.42s
# 900:	learn: 2046.3494163	test: 2733.4285789	best: 2733.3976820 (899)	total: 1.87s	remaining: 4.36s
# 925:	learn: 2042.8489587	test: 2731.7908488	best: 2731.7908488 (925)	total: 1.94s	remaining: 4.34s
# 950:	learn: 2039.5400352	test: 2730.6134213	best: 2730.5803438 (948)	total: 1.99s	remaining: 4.28s
# 975:	learn: 2036.2133840	test: 2729.3062919	best: 2729.3062919 (975)	total: 2.03s	remaining: 4.22s
# 1000:	learn: 2032.5013890	test: 2728.4795042	best: 2728.4795042 (1000)	total: 2.08s	remaining: 4.16s
# 1025:	learn: 2029.4946873	test: 2727.1760479	best: 2727.1760479 (1025)	total: 2.13s	remaining: 4.1s
# 1050:	learn: 2026.9851369	test: 2726.1883646	best: 2726.1762478 (1048)	total: 2.19s	remaining: 4.07s
# 1075:	learn: 2023.8027496	test: 2725.4483683	best: 2725.3761837 (1071)	total: 2.24s	remaining: 4s
# 1100:	learn: 2020.5092148	test: 2723.6048378	best: 2723.6048378 (1100)	total: 2.29s	remaining: 3.95s
# 1125:	learn: 2017.2633108	test: 2722.3115023	best: 2722.2836997 (1124)	total: 2.34s	remaining: 3.9s
# 1150:	learn: 2014.3261642	test: 2721.1280327	best: 2721.0718641 (1147)	total: 2.4s	remaining: 3.86s
# 1175:	learn: 2011.9212887	test: 2720.0364632	best: 2720.0364632 (1175)	total: 2.46s	remaining: 3.81s
# 1200:	learn: 2009.1818304	test: 2718.7341325	best: 2718.6901613 (1199)	total: 2.51s	remaining: 3.76s
# 1225:	learn: 2005.9989798	test: 2717.8290208	best: 2717.8290208 (1225)	total: 2.56s	remaining: 3.71s
# 1250:	learn: 2003.0231640	test: 2716.9446161	best: 2716.8513045 (1245)	total: 2.62s	remaining: 3.66s
# 1275:	learn: 2000.7259992	test: 2716.2321274	best: 2716.2321274 (1275)	total: 2.67s	remaining: 3.61s
# 1300:	learn: 1997.9282849	test: 2714.9969520	best: 2714.9969520 (1300)	total: 2.72s	remaining: 3.55s
# 1325:	learn: 1995.3742029	test: 2714.2190423	best: 2714.1732402 (1323)	total: 2.77s	remaining: 3.49s
# 1350:	learn: 1992.5930883	test: 2713.3820712	best: 2713.3672999 (1346)	total: 2.82s	remaining: 3.44s
# 1375:	learn: 1989.9025693	test: 2712.6190910	best: 2712.5613728 (1371)	total: 2.87s	remaining: 3.39s
# 1400:	learn: 1986.6671880	test: 2711.2605152	best: 2711.2605152 (1400)	total: 2.94s	remaining: 3.35s
# 1425:	learn: 1983.4895116	test: 2710.4754743	best: 2710.4754743 (1425)	total: 2.98s	remaining: 3.29s
# 1450:	learn: 1980.7642092	test: 2709.8513915	best: 2709.8513915 (1450)	total: 3.04s	remaining: 3.24s
# 1475:	learn: 1977.9446828	test: 2708.9628987	best: 2708.9625678 (1474)	total: 3.1s	remaining: 3.2s
# 1500:	learn: 1975.4780275	test: 2708.5840600	best: 2708.5749158 (1499)	total: 3.15s	remaining: 3.14s
# 1525:	learn: 1973.3225498	test: 2708.0796887	best: 2708.0796887 (1525)	total: 3.19s	remaining: 3.08s
# 1550:	learn: 1970.4880039	test: 2707.3834348	best: 2707.3834348 (1550)	total: 3.25s	remaining: 3.03s
# 1575:	learn: 1968.2223191	test: 2706.5575971	best: 2706.5575971 (1575)	total: 3.3s	remaining: 2.99s
# 1600:	learn: 1965.5993542	test: 2705.9360560	best: 2705.9327730 (1599)	total: 3.36s	remaining: 2.94s
# 1625:	learn: 1963.3231826	test: 2705.7600648	best: 2705.7566884 (1621)	total: 3.41s	remaining: 2.88s
# 1650:	learn: 1960.9083736	test: 2705.1845111	best: 2705.1685532 (1648)	total: 3.47s	remaining: 2.83s
# 1675:	learn: 1958.6355077	test: 2704.6419073	best: 2704.6419073 (1675)	total: 3.53s	remaining: 2.79s
# 1700:	learn: 1956.3444622	test: 2703.9857018	best: 2703.9857018 (1700)	total: 3.58s	remaining: 2.73s
# 1725:	learn: 1954.0610121	test: 2703.2641187	best: 2703.1758024 (1720)	total: 3.63s	remaining: 2.68s
# 1750:	learn: 1951.4103393	test: 2702.7210335	best: 2702.7210335 (1750)	total: 3.68s	remaining: 2.63s
# 1775:	learn: 1949.4729749	test: 2701.8953767	best: 2701.8953767 (1775)	total: 3.73s	remaining: 2.57s
# 1800:	learn: 1947.1049810	test: 2701.6896638	best: 2701.5846439 (1790)	total: 3.78s	remaining: 2.52s
# 1825:	learn: 1944.6222005	test: 2701.0071002	best: 2701.0071002 (1825)	total: 3.83s	remaining: 2.46s
# 1850:	learn: 1942.3238984	test: 2700.5302360	best: 2700.5302360 (1850)	total: 3.9s	remaining: 2.42s
# 1875:	learn: 1940.1830589	test: 2699.6669935	best: 2699.6669935 (1875)	total: 3.95s	remaining: 2.37s
# 1900:	learn: 1937.8342517	test: 2699.2286804	best: 2699.2285628 (1899)	total: 4s	remaining: 2.31s
# 1925:	learn: 1935.4972990	test: 2698.9531143	best: 2698.9438694 (1924)	total: 4.05s	remaining: 2.26s
# 1950:	learn: 1933.4531256	test: 2698.7326480	best: 2698.7326480 (1950)	total: 4.1s	remaining: 2.21s
# 1975:	learn: 1931.0346804	test: 2698.3640210	best: 2698.3640210 (1975)	total: 4.16s	remaining: 2.15s
# 2000:	learn: 1928.6263703	test: 2697.3082189	best: 2697.3082189 (2000)	total: 4.21s	remaining: 2.1s
# 2025:	learn: 1926.4610427	test: 2697.0512930	best: 2696.9854111 (2022)	total: 4.26s	remaining: 2.05s
# 2050:	learn: 1924.3833415	test: 2697.0224377	best: 2696.8561815 (2045)	total: 4.31s	remaining: 1.99s
# 2075:	learn: 1921.8138612	test: 2696.6308945	best: 2696.6308945 (2075)	total: 4.37s	remaining: 1.95s
# 2100:	learn: 1919.6697591	test: 2696.4072136	best: 2696.4072136 (2100)	total: 4.42s	remaining: 1.89s
# 2125:	learn: 1917.6939163	test: 2696.3394360	best: 2696.2201547 (2114)	total: 4.47s	remaining: 1.84s
# 2150:	learn: 1915.5241359	test: 2695.6726650	best: 2695.5752512 (2149)	total: 4.53s	remaining: 1.79s
# 2175:	learn: 1913.0695983	test: 2695.3759015	best: 2695.1485295 (2169)	total: 4.58s	remaining: 1.73s
# 2200:	learn: 1911.0164921	test: 2695.1458129	best: 2695.1458129 (2200)	total: 4.63s	remaining: 1.68s
# 2225:	learn: 1908.5866078	test: 2694.6476241	best: 2694.6476241 (2225)	total: 4.68s	remaining: 1.63s
# 2250:	learn: 1906.4867342	test: 2694.2838905	best: 2694.2838905 (2250)	total: 4.73s	remaining: 1.57s
# 2275:	learn: 1904.3639949	test: 2694.1596192	best: 2694.1414126 (2274)	total: 4.78s	remaining: 1.52s
# 2300:	learn: 1901.7736610	test: 2693.7430905	best: 2693.5048144 (2294)	total: 4.83s	remaining: 1.47s
# 2325:	learn: 1899.6701351	test: 2693.3795833	best: 2693.2715311 (2314)	total: 4.9s	remaining: 1.42s
# 2350:	learn: 1897.7036341	test: 2693.2487041	best: 2693.0863710 (2336)	total: 4.95s	remaining: 1.37s
# 2375:	learn: 1895.7615752	test: 2693.0450214	best: 2692.9203834 (2366)	total: 5s	remaining: 1.31s
# 2400:	learn: 1893.8912059	test: 2693.0819528	best: 2692.9203834 (2366)	total: 5.05s	remaining: 1.26s
# 2425:	learn: 1891.9747879	test: 2692.5753569	best: 2692.5244050 (2424)	total: 5.1s	remaining: 1.21s
# 2450:	learn: 1890.1161608	test: 2692.2730991	best: 2692.2730991 (2450)	total: 5.16s	remaining: 1.16s
# 2475:	learn: 1888.4006897	test: 2692.1428959	best: 2692.0836050 (2461)	total: 5.22s	remaining: 1.1s
# 2500:	learn: 1886.3860676	test: 2691.8252828	best: 2691.8252828 (2500)	total: 5.29s	remaining: 1.05s
# 2525:	learn: 1884.6091331	test: 2691.9930730	best: 2691.8252828 (2500)	total: 5.35s	remaining: 1s
# 2550:	learn: 1882.5257110	test: 2691.4273647	best: 2691.4019144 (2548)	total: 5.42s	remaining: 953ms
# 2575:	learn: 1880.5446457	test: 2691.5635673	best: 2691.4019144 (2548)	total: 5.48s	remaining: 902ms
# 2600:	learn: 1878.4636965	test: 2691.4888700	best: 2691.4019144 (2548)	total: 5.54s	remaining: 850ms
# 2625:	learn: 1876.6725946	test: 2691.5828004	best: 2691.3123417 (2619)	total: 5.59s	remaining: 796ms
# 2650:	learn: 1874.9265277	test: 2691.3381350	best: 2691.3123417 (2619)	total: 5.64s	remaining: 743ms
# 2675:	learn: 1873.1005340	test: 2691.1947202	best: 2691.1507255 (2660)	total: 5.69s	remaining: 689ms
# 2700:	learn: 1871.5239697	test: 2691.1566621	best: 2691.0464145 (2693)	total: 5.74s	remaining: 635ms
# 2725:	learn: 1869.3315032	test: 2690.9470882	best: 2690.8280531 (2721)	total: 5.79s	remaining: 582ms
# 2750:	learn: 1867.5020721	test: 2690.9689944	best: 2690.8280531 (2721)	total: 5.83s	remaining: 528ms
# 2775:	learn: 1865.5555779	test: 2690.7699494	best: 2690.6878731 (2771)	total: 5.91s	remaining: 477ms
# 2800:	learn: 1863.9348757	test: 2690.7426898	best: 2690.5720880 (2792)	total: 5.96s	remaining: 423ms
# 2825:	learn: 1862.1252258	test: 2690.5720240	best: 2690.2391522 (2817)	total: 6s	remaining: 370ms
# 2850:	learn: 1860.4390216	test: 2690.4771591	best: 2690.2391522 (2817)	total: 6.05s	remaining: 316ms
# 2875:	learn: 1858.7921483	test: 2690.4333729	best: 2690.2391522 (2817)	total: 6.1s	remaining: 263ms
# 2900:	learn: 1857.0321620	test: 2690.3012259	best: 2690.2391522 (2817)	total: 6.16s	remaining: 210ms
# 2925:	learn: 1855.2504260	test: 2690.1703814	best: 2690.1703814 (2925)	total: 6.21s	remaining: 157ms
# 2950:	learn: 1853.3916286	test: 2689.8205332	best: 2689.8157801 (2949)	total: 6.25s	remaining: 104ms
# 2975:	learn: 1851.9280602	test: 2689.7949740	best: 2689.7586757 (2955)	total: 6.31s	remaining: 50.9ms
# 2999:	learn: 1850.1094901	test: 2689.7396500	best: 2689.7202664 (2996)	total: 6.36s	remaining: 0us
#
# bestTest = 2689.720266
# bestIteration = 2996
#
# Shrink model to first 2997 iterations.

# %%
#final_model.get_all_params()

# %%
def rmse(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
final_pred = model.predict(X_val)

# %%
score = rmse(y_val, final_pred)
score
# Out:
# 2436.513700181098

# %%
final_score = rmse(np.exp(y_val), np.exp(final_pred))
final_score
# Out:
# /home/sam/anaconda3/envs/nb_env/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_9049/4258829870.py:1: RuntimeWarning: overflow encountered in exp
#   final_score = rmse(np.exp(y_val), np.exp(final_pred))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 final_score = rmse(np.exp(y_val), np.exp(final_pred))
#       2 final_score
#
# Cell In[51], line 2, in rmse(y, y_pred)
#       1 def rmse(y, y_pred):
# ----> 2     return np.sqrt(mean_squared_error(y, y_pred))
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/metrics/_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 """Check that y_true and y_pred belong to the same regression task.
#      67
#      68 Parameters
#    (...)
#      97     correct keyword.
#      98 """
#      99 check_consistent_length(y_true, y_pred)
# --> 100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
#df_test = pd.read_csv('/home/sam/Desktop/test_features.csv')
df_test = df_val
#df_test

# %%
df_test['PopCount'].describe()
# Out:
# count    18292.000000
# mean      1158.546960
# std       3141.469928
# min          0.000000
# 25%          0.000000
# 50%         45.000000
# 75%        652.250000
# max      44636.000000
# Name: PopCount, dtype: float64

# %%
test_target = df_test['PopCount']
test_target_log = np.log1p(test_target)

xtest = df_test.drop('PopCount', axis=1)
xtest.shape
# Out:
# (18292, 19)

# %%
test_pred = model.predict(xtest)
test_pred
# Out:
# array([6770.2134606 , 4960.29619994,  691.08943546, ..., 2087.56925461, 1793.71903561,
#        3578.53365146])

# %%
test_score = rmse(np.exp(test_target_log), np.exp(test_pred))
print(test_score)
test_score = rmse((test_target_log), (test_pred))
print(test_score)
# Out:
# /tmp/ipykernel_9049/1770958788.py:1: RuntimeWarning: overflow encountered in exp
#   test_score = rmse(np.exp(test_target_log), np.exp(test_pred))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 test_score = rmse(np.exp(test_target_log), np.exp(test_pred))
#       2 print(test_score)
#       3 test_score = rmse((test_target_log), (test_pred))
#
# Cell In[51], line 2, in rmse(y, y_pred)
#       1 def rmse(y, y_pred):
# ----> 2     return np.sqrt(mean_squared_error(y, y_pred))
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/metrics/_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/metrics/_regression.py:101, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      99 check_consistent_length(y_true, y_pred)
#     100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
# --> 101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#     104     y_true = y_true.reshape((-1, 1))
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~/anaconda3/envs/nb_env/lib/python3.10/site-packages/sklearn/utils/validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input contains infinity or a value too large for dtype('float64').

# %%
pd.set_option('display.max_rows', 15)  # Set to None for more rows
pd.set_option('display.max_columns', 15)  # Set to None for more columns

print(np.exp(test_pred))
print(np.exp(test_target_log))
# Out:
# [            inf             inf 1.36876321e+300 ...             inf             inf
#              inf]
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#           ...
# 18287    15763.0
# 18288     5520.0
# 18289     5106.0
# 18290      220.0
# 18291     2880.0
# Name: PopCount, Length: 18292, dtype: float64
# /tmp/ipykernel_9049/970149937.py:4: RuntimeWarning: overflow encountered in exp
#   print(np.exp(test_pred))

# %%
print(np.exp(test_pred))
print(np.exp(test_target_log))
# Out:
# [            inf             inf 1.36876321e+300 ...             inf             inf
#              inf]
# 0            1.0
# 1            1.0
# 2            1.0
# 3            1.0
# 4            1.0
#           ...
# 18287    15763.0
# 18288     5520.0
# 18289     5106.0
# 18290      220.0
# 18291     2880.0
# Name: PopCount, Length: 18292, dtype: float64
# /tmp/ipykernel_9049/893835449.py:1: RuntimeWarning: overflow encountered in exp
#   print(np.exp(test_pred))
